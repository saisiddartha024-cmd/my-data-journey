# %%
def add(n1,n2):
    print(n1+n2)

# %%
add(10,20)
# Out:
# 30

# %%
number1= 10

# %%
number2= input("please enter a number:")
# Out:
# please enter a number: 20

# %%
add(number1, number2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 add(number1, number2)
#
# Cell In[1], line 2, in add(n1, n2)
#       1 def add(n1,n2):
# ----> 2     print(n1+n2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    #want to attempt this code
    #may have an error
    result = 10+ "10"
except:
    print("hey you are not adding correctly")
else:
    print("add went well")
    print(result)
# Out:
# hey you are not adding correctly

# %%
result
# Out:
# 20

# %%
try:
    #want to attempt this code
    #may have an error
    result = 10+ 10
except:
    print("hey you are not adding correctly")
else:
    print("add went well")
    print(result)
# Out:
# add went well
# 20

# %%
try:
    f = open('testfile','r')
    f.write("write a test line")
except TypeError:
    print("There was a type error")
except OSError:
    print("hey you have an OS error")
finally:
    print("I always run")
# Out:
# hey you have an OS error
# I always run

# %%
try:
    f = open('testfile','w')
    f.write("write a test line")
except TypeError:
    print("There was a type error")
except OSError:
    print("hey you have an OS error")
finally:
    print("I always run")
# Out:
# I always run

# %%
def ask_for_int():
    try:
        result = int(input("please provide number: "))
    except:
        print("whoops! that is not a number")
    finally:
        print("end of try/except/finally")

# %%
ask_for_int()
# Out:
# please provide number:  20
# end of try/except/finally

# %%
ask_for_int()
# Out:
# please provide number:  word
# whoops! that is not a number
# end of try/except/finally

# %%
def ask_for_int():
    while True:
        try:
            result = int(input("please provide number: "))
        except:
            print("whoops! that is not a number")
            continue
        else:
            print("yes thank you")
            break
        finally:
            print("end of try/except/finally")

# %%
ask_for_int()
# Out:
# please provide number:  200
# yes thank you
# end of try/except/finally

# %%
ask_for_int()
# Out:
# please provide number:  siddarth
# whoops! that is not a number
# end of try/except/finally
# please provide number:  sai
# whoops! that is not a number
# end of try/except/finally
# please provide number:  1
# yes thank you
# end of try/except/finally
