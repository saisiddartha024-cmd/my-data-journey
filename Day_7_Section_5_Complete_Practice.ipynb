# %%
# Day 7 – Section 5 Complete Practice
# Sai Siddartha Thota | 13 Dec 2025
# Finished if/elif/else, for loops, while loops, useful operators, and list comprehensions!

print("=== MY DAILY CODING PROGRESS TRACKER ===\n")

# My study hours last 7 days
study_hours = [5, 6, 4, 7, 5, 8, 6]

# 1. For loop to show each day
print("Daily study hours:")
for day, hours in enumerate(study_hours, start=1):
    print(f"Day {day}: {hours} hours")

print()

# 2. Calculate total and average using a for loop
total = 0
for h in study_hours:
    total += h
average = total / len(study_hours)

print(f"Total hours this week: {total}")
print(f"Average per day: {average:.1f} hours")

print()

# 3. If/elif/else to check progress
if average >= 7:
    print("Excellent week! Keep this up!")
elif average >= 5:
    print("Good consistent effort — you're building momentum")
else:
    print("Room to improve — but you're still showing up!")

print()

# 4. While loop example — countdown to goal
goal = 600
current = total * 10  # rough estimate for whole journey
print("Journey to 600-hour goal:")
while current < goal:
    print(f"{current} hours done — {goal - current} to go")
    current += 100  # adding 100 hours at a time (imagining future weeks)
    if current >= goal:
        print("GOAL REACHED! Ready for interviews!")
        break

print()

# 5. List comprehensions — the cool way
# Normal way
squares = []
for x in range(1, 11):
    squares.append(x**2)
print("Squares (normal way):", squares)

# Pro way with comprehension
squares_pro = [x**2 for x in range(1, 11)]
print("Squares (comprehension):", squares_pro)

# Only even numbers squared
even_squares = [x**2 for x in range(1, 11) if x % 2 == 0]
print("Even squares only:", even_squares)

# Quick test with my study hours
good_days = [h for h in study_hours if h >= 6]
print(f"Good study days (6+ hours): {len(good_days)} out of 7")

print("\nSection 5 done.")
print("Feeling stronger every day.")# Day 7 – Section 5 Complete Practice
# Sai Siddartha Thota | 14 Dec 2025
# Finished if/elif/else, for loops, while loops, useful operators, and list comprehensions!

print("=== MY DAILY CODING PROGRESS TRACKER ===\n")

# My study hours last 7 days
study_hours = [5, 6, 4, 7, 5, 8, 6]

# 1. For loop to show each day
print("Daily study hours:")
for day, hours in enumerate(study_hours, start=1):
    print(f"Day {day}: {hours} hours")

print()

# 2. Calculate total and average using a for loop
total = 0
for h in study_hours:
    total += h
average = total / len(study_hours)

print(f"Total hours this week: {total}")
print(f"Average per day: {average:.1f} hours")

print()

# 3. If/elif/else to check progress
if average >= 7:
    print("Excellent week! Keep this up!")
elif average >= 5:
    print("Good consistent effort — you're building momentum")
else:
    print("Room to improve — but you're still showing up!")

print()

# 4. While loop example — countdown to goal
goal = 600
current = total*10  # rough estimate for whole journey
print("Journey to 600-hour goal:")
while current < goal:
    print(f"{current} hours done — {goal - current} to go")
    current += 100  # adding 100 hours at a time (imagining future weeks)
    if current >= goal:
        print("GOAL REACHED! Ready for interviews!")
        break

print()

# 5. List comprehensions — the cool way
# Normal way
squares = []
for x in range(1, 11):
    squares.append(x**2)
print("Squares (normal way):", squares)

# Pro way with comprehension
squares_pro = [x**2 for x in range(1, 11)]
print("Squares (comprehension):", squares_pro)

# Only even numbers squared
even_squares = [x**2 for x in range(1, 11) if x % 2 == 0]
print("Even squares only:", even_squares)

# Quick test with my study hours
good_days = [h for h in study_hours if h >= 6]
print(f"Good study days (6+ hours): {len(good_days)} out of 7")

print("\nSection 5 done.")
print("Feeling stronger every day.")
# Out:
# === MY DAILY CODING PROGRESS TRACKER ===
#
# Daily study hours:
# Day 1: 5 hours
# Day 2: 6 hours
# Day 3: 4 hours
# Day 4: 7 hours
# Day 5: 5 hours
# Day 6: 8 hours
# Day 7: 6 hours
#
# Total hours this week: 41
# Average per day: 5.9 hours
#
# Good consistent effort — you're building momentum
#
# Journey to 600-hour goal:
# 410 hours done — 190 to go
# 510 hours done — 90 to go
# GOAL REACHED! Ready for interviews!
#
# Squares (normal way): [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Squares (comprehension): [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Even squares only: [4, 16, 36, 64, 100]
# Good study days (6+ hours): 4 out of 7
#
# Section 5 done.
# Feeling stronger every day.
# === MY DAILY CODING PROGRESS TRACKER ===
#
# Daily study hours:
# Day 1: 5 hours
# Day 2: 6 hours
# Day 3: 4 hours
# Day 4: 7 hours
# Day 5: 5 hours
# Day 6: 8 hours
# Day 7: 6 hours
#
# Total hours this week: 41
# Average per day: 5.9 hours
#
# Good consistent effort — you're building momentum
#
# ...
