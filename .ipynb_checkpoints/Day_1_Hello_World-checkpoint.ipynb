# %%
print("My name is Sai Siddartha")
print("I started learning Python on 8 December 2025")
print("This is my first real Jupyter notebook")
2 + 2
# Out:
# My name is Sai Siddartha
# I started learning Python on 8 December 2025
# This is my first real Jupyter notebook
# 4
